# %%
import pandas as pd

# %%
df = pd.read_csv("Titanic-Dataset.csv")

# %%
# 1. 
df.shape
# Out:
# (891, 12)

# %%
# 2.
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp
# 466          467         0       2  Campbell, Mr. William  male   NaN      0  \
# 395          396         0       3    Johansson, Mr. Erik  male  22.0      0
# 637          638         0       2    Collyer, Mr. Harvey  male  31.0      1
# 732          733         0       2   Knight, Mr. Robert J  male   NaN      0
# 495          496         0       3  Yousseff, Mr. Gerious  male   NaN      0
#
#      Parch      Ticket     Fare Cabin Embarked
# 466      0      239853   0.0000   NaN        S
# 395      0      350052   7.7958   NaN        S
# 637      1  C.A. 31921  26.2500   NaN        S
# 732      0      239855   0.0000   NaN        S
# 495      0        2627  14.4583   NaN        C

# %%
# 3. 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df= pd.read_csv("Titanic-Dataset.csv", dtype={"Age":int})
# Out:
# c:\Users\MANYA\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234: RuntimeWarning: invalid value encountered in cast
#   chunks = self._reader.read_low_memory(nrows)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\MANYA\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:1129, in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('int32') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df= pd.read_csv("Titanic-Dataset.csv", dtype={"Age":int})
#
# ...

# %%
# 4. 
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# 5. 
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   891.000000  891.000000  891.000000  714.000000  891.000000  \
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# 6.
df.duplicated().sum()
# Out:
# 0

# %%
# 7. 
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652  \
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df.corr(numeric_only=True)['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %% [markdown]
# # Univatiate Analysis

# %% [markdown]
# ## 1. Categorical Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df["Survived"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Survived'>

# %%
df["Embarked"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
sns.countplot(df['Pclass'])
# Out:
# <Axes: ylabel='count'>

# %%
df["Sex"].value_counts().plot(kind='pie', autopct="%0.2f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 2. Numerical Data

# %%
df['Age'].plot(kind='hist',bins=5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.distplot(df["Age"])
# Out:
# C:\Users\MANYA\AppData\Local\Temp\ipykernel_12304\2732350774.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(df["Age"])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: >

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df["Age"].min()
# Out:
# 0.42

# %%
df["Age"].skew()
# Out:
# 0.38910778230082704

# %% [markdown]
# # Bivariate analysis

# %%
tips = sns.load_dataset("tips")

# %%
flights = sns.load_dataset("flights")

# %%
iris = sns.load_dataset("iris")

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass
# 182          183         0       3  \
# 639          640         0       3
# 101          102         0       3
# 664          665         1       3
# 608          609         1       2
#
#                                                   Name     Sex   Age  SibSp
# 182              Asplund, Master. Clarence Gustaf Hugo    male   9.0      4  \
# 639                         Thorneycroft, Mr. Percival    male   NaN      1
# 101                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 664                        Lindqvist, Mr. Eino William    male  20.0      1
# 608  Laroche, Mrs. Joseph (Juliette Marie Louise La...  female  22.0      1
#
#      Parch             Ticket     Fare Cabin Embarked
# 182      2             347077  31.3875   NaN        S
# 639      0             376564  16.1000   NaN        S
# 101      0             349215   7.8958   NaN        S
# 664      0  STON/O 2. 3101285   7.9250   NaN        S
# ...

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 133       12.26  2.00  Female     No  Thur   Lunch     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 46        22.23  5.00    Male     No   Sun  Dinner     2
# 43         9.68  1.32    Male     No   Sun  Dinner     2

# %%
flights.sample(5)
# Out:
#      year month  passengers
# 45   1952   Oct         191
# 59   1953   Dec         201
# 24   1951   Jan         145
# 127  1959   Aug         559
# 56   1953   Sep         237

# %%
iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 94            5.6          2.7           4.2          1.3  versicolor
# 32            5.2          4.1           1.5          0.1      setosa
# 133           6.3          2.8           5.1          1.5   virginica
# 101           5.8          2.7           5.1          1.9   virginica
# 59            5.2          2.7           3.9          1.4  versicolor

# %% [markdown]
# # Numerical - Numerical

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],hue=tips['sex'],style=tips['smoker'],size=tips['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.pairplot(iris, hue='species')

# %%
newd = flights.groupby("year")['passengers'].sum()

# %%
sns.lineplot(newd)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
newd = flights.pivot_table(values='passengers', index='month',columns='year')

# %%
sns.heatmap(newd)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(newd)

# %% [markdown]
# ## N-C

# %%
sns.barplot(x=df["Pclass"],y=df["Fare"], hue = df["Sex"])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.boxplot(x=df["Pclass"],y=df["Age"],hue=df["Survived"])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.distplot(df[df["Survived"]==0]["Age"], hist = False)
sns.distplot(df[df["Survived"]==1]["Age"], hist = False)
# Out:
# C:\Users\MANYA\AppData\Local\Temp\ipykernel_12304\484512758.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df["Survived"]==0]["Age"], hist = False)
# C:\Users\MANYA\AppData\Local\Temp\ipykernel_12304\484512758.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # C-C

# %%
sns.heatmap(pd.crosstab(df["Pclass"],df["Survived"]))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
(df.groupby("Pclass")["Survived"].mean()*100).plot(kind="bar")
# Out:
# <Axes: xlabel='Pclass'>

# %%
sns.clustermap(pd.crosstab(df['Parch'], df['Survived']))
