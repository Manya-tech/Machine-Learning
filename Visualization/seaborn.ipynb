# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
plt.style.use("fivethirtyeight")

# %%
df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(df, x="total_bill",y="tip")

# %%
sns.relplot(df, x="total_bill",y="tip", hue="smoker")

# %%
sns.relplot(df, x="total_bill",y="tip", hue="smoker", style='sex')

# %%
sns.relplot(df, x="total_bill",y="tip", hue="smoker", style='sex', size='size')

# %%
sns.relplot(df, x="total_bill",y="tip", hue="smoker", style='sex', size='size', sizes=(15,200))

# %%
sns.scatterplot(df, x="total_bill",y="tip", hue="smoker", style='sex', size='size', sizes=(15,200))
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
